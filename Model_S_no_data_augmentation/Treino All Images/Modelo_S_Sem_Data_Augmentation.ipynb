# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
from tensorflow import keras

# Diretórios de dados
base_dir = 'Imagens/'
train_dirs = [os.path.join(base_dir, f'train/train{i}/') for i in range(1, 4)]
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

# %%
# Configuração do ImageDataGenerator
datagen = ImageDataGenerator(rescale=1./255)

IMG_SIZE = 32
BATCH_SIZE = 24
num_classes = 10

# Função para carregar e preprocessar dados de múltiplos diretórios
def load_data_from_directories(directories, img_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE):
    # Inicializa listas vazias para armazenar os dados das imagens e os rótulos
    data, labels = [], []
    
    # Itera sobre cada diretório na lista de diretórios fornecida
    for directory in directories:
        # Cria um gerador de dados para o diretório atual
        data_gen = datagen.flow_from_directory(
            directory,                # Diretório atual de onde as imagens serão carregadas
            target_size=img_size,     # Redimensiona as imagens para o tamanho especificado (img_size)
            batch_size=batch_size,    # Número de imagens a serem carregadas em cada lote (batch)
            class_mode='categorical', # Define o modo de classe como 'categorical' para classificação
            shuffle=True              # Embaralha as imagens para garantir uma mistura aleatória
        )
        
        # Itera sobre o gerador de dados para carregar todos os lotes de imagens e rótulos
        for _ in range(len(data_gen)):
            # Carrega o próximo lote de dados e rótulos do gerador
            batch_data, batch_labels = data_gen.next()
            # Adiciona o lote de dados à lista de dados
            data.append(batch_data)
            # Adiciona o lote de rótulos à lista de rótulos
            labels.append(batch_labels)
    
    # Concatena todas as listas de lotes em um único array para dados e rótulos, respectivamente
    return np.vstack(data), np.vstack(labels)

# Carregar dados de treino de múltiplos diretórios
# Chama a função definida acima passando a lista de diretórios de treino, o tamanho das imagens e o tamanho do lote
X_train, y_train = load_data_from_directories(train_dirs, img_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE)


validation_dataset = datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)

test_dataset = datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.

# %%
#Criar o modelo

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3), kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),

    Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.4),

    Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.4),

    Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.4),

    Flatten(),
    Dense(512, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.5),

    Dense(num_classes, activation='softmax')
    ])

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.00001)

# %%
# Treinar o modelo
history = model.fit(X_train, y_train, epochs=100, validation_data=validation_dataset, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 938/938 [==============================] - 27s 27ms/step - loss: 3.0374 - accuracy: 0.3336 - val_loss: 2.6079 - val_accuracy: 0.4123 - lr: 0.0010
# Epoch 2/100
# 938/938 [==============================] - 26s 27ms/step - loss: 2.3145 - accuracy: 0.4587 - val_loss: 2.1617 - val_accuracy: 0.4877 - lr: 0.0010
# Epoch 3/100
# 938/938 [==============================] - 25s 27ms/step - loss: 1.9903 - accuracy: 0.5221 - val_loss: 1.8013 - val_accuracy: 0.5642 - lr: 0.0010
# Epoch 4/100
# 938/938 [==============================] - 24s 26ms/step - loss: 1.8442 - accuracy: 0.5598 - val_loss: 1.8971 - val_accuracy: 0.5486 - lr: 0.0010
# Epoch 5/100
# 938/938 [==============================] - 23s 24ms/step - loss: 1.8036 - accuracy: 0.5772 - val_loss: 1.6523 - val_accuracy: 0.6344 - lr: 0.0010
# Epoch 6/100
# 938/938 [==============================] - 23s 24ms/step - loss: 1.7801 - accuracy: 0.6005 - val_loss: 1.8068 - val_accuracy: 0.5993 - lr: 0.0010
# Epoch 7/100
# 938/938 [==============================] - 23s 24ms/step - loss: 1.7627 - accuracy: 0.6155 - val_loss: 1.6173 - val_accuracy: 0.6653 - lr: 0.0010
# Epoch 8/100
# 938/938 [==============================] - 23s 24ms/step - loss: 1.7472 - accuracy: 0.6270 - val_loss: 1.6095 - val_accuracy: 0.6716 - lr: 0.0010
# Epoch 9/100
# 938/938 [==============================] - 24s 25ms/step - loss: 1.7282 - accuracy: 0.6347 - val_loss: 1.6568 - val_accuracy: 0.6593 - lr: 0.0010
# Epoch 10/100
# 938/938 [==============================] - 26s 27ms/step - loss: 1.7183 - accuracy: 0.6400 - val_loss: 1.5559 - val_accuracy: 0.6943 - lr: 0.0010
# Epoch 11/100
# 938/938 [==============================] - 24s 26ms/step - loss: 1.7005 - accuracy: 0.6468 - val_loss: 1.5938 - val_accuracy: 0.6767 - lr: 0.0010
# Epoch 12/100
# 938/938 [==============================] - 23s 24ms/step - loss: 1.6852 - accuracy: 0.6515 - val_loss: 1.5821 - val_accuracy: 0.6824 - lr: 0.0010
# Epoch 13/100
# 938/938 [==============================] - 23s 24ms/step - loss: 1.6768 - accuracy: 0.6570 - val_loss: 1.6212 - val_accuracy: 0.6713 - lr: 0.0010
# Epoch 14/100
# 938/938 [==============================] - 23s 24ms/step - loss: 1.6628 - accuracy: 0.6580 - val_loss: 1.6427 - val_accuracy: 0.6605 - lr: 0.0010
# Epoch 15/100
# 938/938 [==============================] - 23s 24ms/step - loss: 1.6427 - accuracy: 0.6611 - val_loss: 1.4548 - val_accuracy: 0.7266 - lr: 0.0010
# Epoch 16/100
# 938/938 [==============================] - 23s 24ms/step - loss: 1.6313 - accuracy: 0.6672 - val_loss: 1.4902 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 17/100
# 938/938 [==============================] - 24s 25ms/step - loss: 1.6194 - accuracy: 0.6650 - val_loss: 1.5372 - val_accuracy: 0.6946 - lr: 0.0010
# Epoch 18/100
# 938/938 [==============================] - 25s 26ms/step - loss: 1.6097 - accuracy: 0.6717 - val_loss: 1.7474 - val_accuracy: 0.6463 - lr: 0.0010
# Epoch 19/100
# 938/938 [==============================] - 25s 26ms/step - loss: 1.6071 - accuracy: 0.6730 - val_loss: 2.0698 - val_accuracy: 0.5334 - lr: 0.0010
# Epoch 20/100
# 938/938 [==============================] - 23s 25ms/step - loss: 1.6016 - accuracy: 0.6741 - val_loss: 1.4612 - val_accuracy: 0.7200 - lr: 0.0010
# Epoch 21/100
# 938/938 [==============================] - 23s 25ms/step - loss: 1.4381 - accuracy: 0.7166 - val_loss: 1.2573 - val_accuracy: 0.7663 - lr: 1.0000e-04
# Epoch 22/100
# 938/938 [==============================] - 26s 27ms/step - loss: 1.3266 - accuracy: 0.7315 - val_loss: 1.2132 - val_accuracy: 0.7626 - lr: 1.0000e-04
# Epoch 23/100
# 938/938 [==============================] - 25s 27ms/step - loss: 1.2477 - accuracy: 0.7416 - val_loss: 1.0880 - val_accuracy: 0.7870 - lr: 1.0000e-04
# Epoch 24/100
# 938/938 [==============================] - 26s 27ms/step - loss: 1.1878 - accuracy: 0.7495 - val_loss: 1.0895 - val_accuracy: 0.7765 - lr: 1.0000e-04
# Epoch 25/100
# 938/938 [==============================] - 26s 27ms/step - loss: 1.1477 - accuracy: 0.7516 - val_loss: 1.0548 - val_accuracy: 0.7800 - lr: 1.0000e-04
# Epoch 26/100
# 938/938 [==============================] - 25s 27ms/step - loss: 1.0980 - accuracy: 0.7609 - val_loss: 1.0072 - val_accuracy: 0.7857 - lr: 1.0000e-04
# Epoch 27/100
# 938/938 [==============================] - 26s 28ms/step - loss: 1.0625 - accuracy: 0.7642 - val_loss: 0.9917 - val_accuracy: 0.7830 - lr: 1.0000e-04
# Epoch 28/100
# 938/938 [==============================] - 26s 28ms/step - loss: 1.0347 - accuracy: 0.7673 - val_loss: 0.9951 - val_accuracy: 0.7781 - lr: 1.0000e-04
# Epoch 29/100
# 938/938 [==============================] - 26s 28ms/step - loss: 1.0112 - accuracy: 0.7680 - val_loss: 0.9844 - val_accuracy: 0.7793 - lr: 1.0000e-04
# Epoch 30/100
# 938/938 [==============================] - 25s 26ms/step - loss: 0.9974 - accuracy: 0.7693 - val_loss: 0.9294 - val_accuracy: 0.7910 - lr: 1.0000e-04
# Epoch 31/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.9717 - accuracy: 0.7754 - val_loss: 0.9233 - val_accuracy: 0.7871 - lr: 1.0000e-04
# Epoch 32/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.9505 - accuracy: 0.7781 - val_loss: 0.8860 - val_accuracy: 0.7951 - lr: 1.0000e-04
# Epoch 33/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.9362 - accuracy: 0.7786 - val_loss: 0.8576 - val_accuracy: 0.8020 - lr: 1.0000e-04
# Epoch 34/100
# 938/938 [==============================] - 26s 27ms/step - loss: 0.9155 - accuracy: 0.7869 - val_loss: 0.8650 - val_accuracy: 0.8015 - lr: 1.0000e-04
# Epoch 35/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.9084 - accuracy: 0.7840 - val_loss: 0.9051 - val_accuracy: 0.7855 - lr: 1.0000e-04
# Epoch 36/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.8933 - accuracy: 0.7870 - val_loss: 0.8439 - val_accuracy: 0.8030 - lr: 1.0000e-04
# Epoch 37/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.8888 - accuracy: 0.7879 - val_loss: 0.8493 - val_accuracy: 0.8034 - lr: 1.0000e-04
# Epoch 38/100
# 938/938 [==============================] - 25s 26ms/step - loss: 0.8730 - accuracy: 0.7898 - val_loss: 0.8224 - val_accuracy: 0.8085 - lr: 1.0000e-04
# Epoch 39/100
# 938/938 [==============================] - 25s 26ms/step - loss: 0.8603 - accuracy: 0.7941 - val_loss: 0.8280 - val_accuracy: 0.8046 - lr: 1.0000e-04
# Epoch 40/100
# 938/938 [==============================] - 23s 24ms/step - loss: 0.8477 - accuracy: 0.7945 - val_loss: 0.8295 - val_accuracy: 0.8027 - lr: 1.0000e-04
# Epoch 41/100
# 938/938 [==============================] - 23s 24ms/step - loss: 0.8431 - accuracy: 0.7967 - val_loss: 0.8090 - val_accuracy: 0.8098 - lr: 1.0000e-04
# Epoch 42/100
# 938/938 [==============================] - 23s 24ms/step - loss: 0.8372 - accuracy: 0.7969 - val_loss: 0.8102 - val_accuracy: 0.8047 - lr: 1.0000e-04
# Epoch 43/100
# 938/938 [==============================] - 23s 24ms/step - loss: 0.8233 - accuracy: 0.7985 - val_loss: 0.7853 - val_accuracy: 0.8166 - lr: 1.0000e-04
# Epoch 44/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.8220 - accuracy: 0.8008 - val_loss: 0.8059 - val_accuracy: 0.8078 - lr: 1.0000e-04
# Epoch 45/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.8064 - accuracy: 0.8029 - val_loss: 0.8254 - val_accuracy: 0.8010 - lr: 1.0000e-04
# Epoch 46/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.7970 - accuracy: 0.8073 - val_loss: 0.7588 - val_accuracy: 0.8205 - lr: 1.0000e-04
# Epoch 47/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7995 - accuracy: 0.8057 - val_loss: 0.7919 - val_accuracy: 0.8123 - lr: 1.0000e-04
# Epoch 48/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7977 - accuracy: 0.8036 - val_loss: 0.8020 - val_accuracy: 0.8048 - lr: 1.0000e-04
# Epoch 49/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7940 - accuracy: 0.8086 - val_loss: 0.7552 - val_accuracy: 0.8238 - lr: 1.0000e-04
# Epoch 50/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7852 - accuracy: 0.8097 - val_loss: 0.7793 - val_accuracy: 0.8168 - lr: 1.0000e-04
# Epoch 51/100
# 938/938 [==============================] - 23s 24ms/step - loss: 0.7871 - accuracy: 0.8080 - val_loss: 0.7524 - val_accuracy: 0.8241 - lr: 1.0000e-04
# Epoch 52/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7787 - accuracy: 0.8084 - val_loss: 0.7528 - val_accuracy: 0.8219 - lr: 1.0000e-04
# Epoch 53/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7681 - accuracy: 0.8126 - val_loss: 0.7868 - val_accuracy: 0.8078 - lr: 1.0000e-04
# Epoch 54/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7698 - accuracy: 0.8121 - val_loss: 0.7641 - val_accuracy: 0.8169 - lr: 1.0000e-04
# Epoch 55/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7718 - accuracy: 0.8112 - val_loss: 0.7526 - val_accuracy: 0.8179 - lr: 1.0000e-04
# Epoch 56/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7680 - accuracy: 0.8114 - val_loss: 0.7536 - val_accuracy: 0.8226 - lr: 1.0000e-04
# Epoch 57/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.7379 - accuracy: 0.8233 - val_loss: 0.7540 - val_accuracy: 0.8205 - lr: 1.0000e-05
# Epoch 58/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7385 - accuracy: 0.8219 - val_loss: 0.7515 - val_accuracy: 0.8221 - lr: 1.0000e-05
# Epoch 59/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.7291 - accuracy: 0.8245 - val_loss: 0.7493 - val_accuracy: 0.8218 - lr: 1.0000e-05
# Epoch 60/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.7254 - accuracy: 0.8243 - val_loss: 0.7527 - val_accuracy: 0.8208 - lr: 1.0000e-05
# Epoch 61/100
# 938/938 [==============================] - 23s 24ms/step - loss: 0.7175 - accuracy: 0.8270 - val_loss: 0.7473 - val_accuracy: 0.8224 - lr: 1.0000e-05
# Epoch 62/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7228 - accuracy: 0.8268 - val_loss: 0.7440 - val_accuracy: 0.8225 - lr: 1.0000e-05
# Epoch 63/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7187 - accuracy: 0.8274 - val_loss: 0.7421 - val_accuracy: 0.8225 - lr: 1.0000e-05
# Epoch 64/100
# 938/938 [==============================] - 23s 24ms/step - loss: 0.7064 - accuracy: 0.8308 - val_loss: 0.7450 - val_accuracy: 0.8216 - lr: 1.0000e-05
# Epoch 65/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7014 - accuracy: 0.8331 - val_loss: 0.7469 - val_accuracy: 0.8206 - lr: 1.0000e-05
# Epoch 66/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7017 - accuracy: 0.8317 - val_loss: 0.7400 - val_accuracy: 0.8251 - lr: 1.0000e-05
# Epoch 67/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.7084 - accuracy: 0.8300 - val_loss: 0.7361 - val_accuracy: 0.8248 - lr: 1.0000e-05
# Epoch 68/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.6953 - accuracy: 0.8306 - val_loss: 0.7315 - val_accuracy: 0.8283 - lr: 1.0000e-05
# Epoch 69/100
# 938/938 [==============================] - 24s 25ms/step - loss: 0.7003 - accuracy: 0.8299 - val_loss: 0.7352 - val_accuracy: 0.8266 - lr: 1.0000e-05
# Epoch 70/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.6961 - accuracy: 0.8317 - val_loss: 0.7374 - val_accuracy: 0.8252 - lr: 1.0000e-05
# Epoch 71/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.6916 - accuracy: 0.8343 - val_loss: 0.7339 - val_accuracy: 0.8273 - lr: 1.0000e-05
# Epoch 72/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.6890 - accuracy: 0.8327 - val_loss: 0.7337 - val_accuracy: 0.8251 - lr: 1.0000e-05
# Epoch 73/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.6839 - accuracy: 0.8354 - val_loss: 0.7332 - val_accuracy: 0.8256 - lr: 1.0000e-05
# Epoch 74/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.6809 - accuracy: 0.8333 - val_loss: 0.7313 - val_accuracy: 0.8259 - lr: 1.0000e-05
# Epoch 75/100
# 938/938 [==============================] - 23s 25ms/step - loss: 0.6815 - accuracy: 0.8370 - val_loss: 0.7300 - val_accuracy: 0.8263 - lr: 1.0000e-05
# Epoch 76/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.6853 - accuracy: 0.8350 - val_loss: 0.7303 - val_accuracy: 0.8266 - lr: 1.0000e-05
# Epoch 77/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.6817 - accuracy: 0.8359 - val_loss: 0.7299 - val_accuracy: 0.8261 - lr: 1.0000e-05
# Epoch 78/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.6741 - accuracy: 0.8396 - val_loss: 0.7233 - val_accuracy: 0.8293 - lr: 1.0000e-05
# Epoch 79/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.6710 - accuracy: 0.8398 - val_loss: 0.7247 - val_accuracy: 0.8276 - lr: 1.0000e-05
# Epoch 80/100
# 938/938 [==============================] - 26s 27ms/step - loss: 0.6706 - accuracy: 0.8388 - val_loss: 0.7243 - val_accuracy: 0.8282 - lr: 1.0000e-05
# Epoch 81/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.6694 - accuracy: 0.8392 - val_loss: 0.7222 - val_accuracy: 0.8286 - lr: 1.0000e-05
# Epoch 82/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.6714 - accuracy: 0.8380 - val_loss: 0.7225 - val_accuracy: 0.8276 - lr: 1.0000e-05
# Epoch 83/100
# 938/938 [==============================] - 26s 27ms/step - loss: 0.6628 - accuracy: 0.8423 - val_loss: 0.7248 - val_accuracy: 0.8269 - lr: 1.0000e-05
# Epoch 84/100
# 938/938 [==============================] - 24s 26ms/step - loss: 0.6624 - accuracy: 0.8399 - val_loss: 0.7221 - val_accuracy: 0.8273 - lr: 1.0000e-05
# Epoch 85/100
# 938/938 [==============================] - 26s 27ms/step - loss: 0.6660 - accuracy: 0.8362 - val_loss: 0.7191 - val_accuracy: 0.8297 - lr: 1.0000e-05
# Epoch 86/100
# 938/938 [==============================] - 26s 27ms/step - loss: 0.6625 - accuracy: 0.8391 - val_loss: 0.7273 - val_accuracy: 0.8263 - lr: 1.0000e-05
# Epoch 87/100
# 938/938 [==============================] - 26s 27ms/step - loss: 0.6593 - accuracy: 0.8398 - val_loss: 0.7169 - val_accuracy: 0.8293 - lr: 1.0000e-05
# Epoch 88/100
# 938/938 [==============================] - 26s 28ms/step - loss: 0.6572 - accuracy: 0.8412 - val_loss: 0.7218 - val_accuracy: 0.8274 - lr: 1.0000e-05
# Epoch 89/100
# 938/938 [==============================] - 26s 28ms/step - loss: 0.6544 - accuracy: 0.8418 - val_loss: 0.7136 - val_accuracy: 0.8310 - lr: 1.0000e-05
# Epoch 90/100
# 938/938 [==============================] - 26s 27ms/step - loss: 0.6554 - accuracy: 0.8412 - val_loss: 0.7205 - val_accuracy: 0.8275 - lr: 1.0000e-05
# Epoch 91/100
# 938/938 [==============================] - 26s 27ms/step - loss: 0.6530 - accuracy: 0.8424 - val_loss: 0.7166 - val_accuracy: 0.8296 - lr: 1.0000e-05
# Epoch 92/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.6449 - accuracy: 0.8438 - val_loss: 0.7198 - val_accuracy: 0.8276 - lr: 1.0000e-05
# Epoch 93/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.6477 - accuracy: 0.8441 - val_loss: 0.7209 - val_accuracy: 0.8260 - lr: 1.0000e-05
# Epoch 94/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.6443 - accuracy: 0.8431 - val_loss: 0.7162 - val_accuracy: 0.8277 - lr: 1.0000e-05
# Epoch 95/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.6361 - accuracy: 0.8504 - val_loss: 0.7134 - val_accuracy: 0.8292 - lr: 1.0000e-05
# Epoch 96/100
# 938/938 [==============================] - 25s 27ms/step - loss: 0.6453 - accuracy: 0.8406 - val_loss: 0.7144 - val_accuracy: 0.8282 - lr: 1.0000e-05
# Epoch 97/100
# 938/938 [==============================] - 26s 28ms/step - loss: 0.6456 - accuracy: 0.8433 - val_loss: 0.7086 - val_accuracy: 0.8294 - lr: 1.0000e-05
# Epoch 98/100
# 938/938 [==============================] - 26s 28ms/step - loss: 0.6462 - accuracy: 0.8419 - val_loss: 0.7115 - val_accuracy: 0.8290 - lr: 1.0000e-05
# Epoch 99/100
# 938/938 [==============================] - 26s 27ms/step - loss: 0.6329 - accuracy: 0.8476 - val_loss: 0.7043 - val_accuracy: 0.8310 - lr: 1.0000e-05
# Epoch 100/100
# 938/938 [==============================] - 26s 27ms/step - loss: 0.6400 - accuracy: 0.8445 - val_loss: 0.7112 - val_accuracy: 0.8293 - lr: 1.0000e-05

# %%
#Saving the model
model.save('Primeiro_treino_AllTrains.h5')
# Out:
# c:\Users\MvCrespo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model = keras.models.load_model('Primeiro_treino_AllTrains.h5')
# Validacao da Rede
val_loss, val_acc = model.evaluate(validation_dataset)
print('val_acc:', val_acc)

# Avaliar o modelo
test_loss, test_acc = model.evaluate(test_dataset)
print(f'Test accuracy: {test_acc}')
# Out:
# 417/417 [==============================] - 4s 9ms/step - loss: 0.7112 - accuracy: 0.8293
# val_acc: 0.8292999863624573
# 417/417 [==============================] - 4s 10ms/step - loss: 0.7319 - accuracy: 0.8225
# Test accuracy: 0.8224999904632568

# %%
# Plotando os resultados
import matplotlib.pyplot as plt

def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training accuracy')
    plt.plot(epochs, val_acc, 'ro-', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

plot_training_history(history)
