# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import image_dataset_from_directory
import os

base_dir = 'Imagens/'

# Diretórios para treino, validação e teste
train_dir = os.path.join(base_dir, 'train/train2/')
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

# %%
IMG_SIZE = 32
BATCH_SIZE = 24

# Configuração do gerador de imagens sem data augmentation
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_dataset = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)

validation_dataset = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)

test_dataset = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


num_classes = 10

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3),kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.00001)

# %%
# Treinar Rede
model.load_weights('Primeiro_treino.h5')
history = model.fit(train_dataset, epochs=100, validation_data=validation_dataset, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.6555 - loss: 1.3017 - val_accuracy: 0.6140 - val_loss: 1.6994 - learning_rate: 0.0010
# Epoch 2/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.6646 - loss: 1.5187 - val_accuracy: 0.6288 - val_loss: 1.7014 - learning_rate: 0.0010
# Epoch 3/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.6735 - loss: 1.5429 - val_accuracy: 0.4291 - val_loss: 2.8255 - learning_rate: 0.0010
# Epoch 4/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.6803 - loss: 1.5963 - val_accuracy: 0.6035 - val_loss: 1.9032 - learning_rate: 0.0010
# Epoch 5/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.6623 - loss: 1.6594 - val_accuracy: 0.6849 - val_loss: 1.6429 - learning_rate: 0.0010
# Epoch 6/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.6764 - loss: 1.6558 - val_accuracy: 0.6422 - val_loss: 1.8038 - learning_rate: 0.0010
# Epoch 7/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.6848 - loss: 1.6661 - val_accuracy: 0.6621 - val_loss: 1.7670 - learning_rate: 0.0010
# Epoch 8/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.6963 - loss: 1.6718 - val_accuracy: 0.6430 - val_loss: 1.8930 - learning_rate: 0.0010
# Epoch 9/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6817 - loss: 1.7185 - val_accuracy: 0.7014 - val_loss: 1.7024 - learning_rate: 0.0010
# Epoch 10/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.6994 - loss: 1.6986 - val_accuracy: 0.6860 - val_loss: 1.7747 - learning_rate: 0.0010
# Epoch 11/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7331 - loss: 1.6248 - val_accuracy: 0.7351 - val_loss: 1.5929 - learning_rate: 1.0000e-04
# Epoch 12/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7451 - loss: 1.5362 - val_accuracy: 0.7330 - val_loss: 1.5640 - learning_rate: 1.0000e-04
# Epoch 13/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7677 - loss: 1.4506 - val_accuracy: 0.7404 - val_loss: 1.5149 - learning_rate: 1.0000e-04
# Epoch 14/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.7665 - loss: 1.4090 - val_accuracy: 0.7497 - val_loss: 1.4597 - learning_rate: 1.0000e-04
# Epoch 15/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7746 - loss: 1.3598 - val_accuracy: 0.7523 - val_loss: 1.4264 - learning_rate: 1.0000e-04
# Epoch 16/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.7847 - loss: 1.3121 - val_accuracy: 0.7494 - val_loss: 1.4071 - learning_rate: 1.0000e-04
# Epoch 17/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.7899 - loss: 1.2733 - val_accuracy: 0.7390 - val_loss: 1.4122 - learning_rate: 1.0000e-04
# Epoch 18/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8006 - loss: 1.2040 - val_accuracy: 0.7529 - val_loss: 1.3398 - learning_rate: 1.0000e-04
# Epoch 19/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8034 - loss: 1.1751 - val_accuracy: 0.7606 - val_loss: 1.3021 - learning_rate: 1.0000e-04
# Epoch 20/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8074 - loss: 1.1456 - val_accuracy: 0.7654 - val_loss: 1.2756 - learning_rate: 1.0000e-04
# Epoch 21/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8076 - loss: 1.1224 - val_accuracy: 0.7354 - val_loss: 1.3552 - learning_rate: 1.0000e-04
# Epoch 22/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8168 - loss: 1.0868 - val_accuracy: 0.7554 - val_loss: 1.2795 - learning_rate: 1.0000e-04
# Epoch 23/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8252 - loss: 1.0417 - val_accuracy: 0.7536 - val_loss: 1.2682 - learning_rate: 1.0000e-04
# Epoch 24/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8219 - loss: 1.0354 - val_accuracy: 0.7661 - val_loss: 1.2038 - learning_rate: 1.0000e-04
# Epoch 25/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8260 - loss: 1.0092 - val_accuracy: 0.7525 - val_loss: 1.2452 - learning_rate: 1.0000e-04
# Epoch 26/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8365 - loss: 0.9812 - val_accuracy: 0.7613 - val_loss: 1.1989 - learning_rate: 1.0000e-04
# Epoch 27/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8231 - loss: 0.9748 - val_accuracy: 0.7625 - val_loss: 1.1798 - learning_rate: 1.0000e-04
# Epoch 28/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8369 - loss: 0.9396 - val_accuracy: 0.7703 - val_loss: 1.1614 - learning_rate: 1.0000e-04
# Epoch 29/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8470 - loss: 0.9073 - val_accuracy: 0.7713 - val_loss: 1.1416 - learning_rate: 1.0000e-04
# Epoch 30/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8421 - loss: 0.9123 - val_accuracy: 0.7601 - val_loss: 1.1770 - learning_rate: 1.0000e-04
# Epoch 31/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8526 - loss: 0.8838 - val_accuracy: 0.7710 - val_loss: 1.1345 - learning_rate: 1.0000e-04
# Epoch 32/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8414 - loss: 0.8848 - val_accuracy: 0.7660 - val_loss: 1.1402 - learning_rate: 1.0000e-04
# Epoch 33/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8502 - loss: 0.8611 - val_accuracy: 0.7748 - val_loss: 1.1051 - learning_rate: 1.0000e-04
# Epoch 34/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.8564 - loss: 0.8383 - val_accuracy: 0.7585 - val_loss: 1.1523 - learning_rate: 1.0000e-04
# Epoch 35/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8553 - loss: 0.8242 - val_accuracy: 0.7621 - val_loss: 1.1308 - learning_rate: 1.0000e-04
# Epoch 36/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8626 - loss: 0.8061 - val_accuracy: 0.7642 - val_loss: 1.1287 - learning_rate: 1.0000e-04
# Epoch 37/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8536 - loss: 0.8092 - val_accuracy: 0.7611 - val_loss: 1.1296 - learning_rate: 1.0000e-04
# Epoch 38/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8607 - loss: 0.7901 - val_accuracy: 0.7627 - val_loss: 1.1246 - learning_rate: 1.0000e-04
# Epoch 39/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.8685 - loss: 0.7662 - val_accuracy: 0.7735 - val_loss: 1.0930 - learning_rate: 1.0000e-05
# Epoch 40/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8667 - loss: 0.7708 - val_accuracy: 0.7759 - val_loss: 1.0897 - learning_rate: 1.0000e-05
# Epoch 41/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8691 - loss: 0.7743 - val_accuracy: 0.7753 - val_loss: 1.0892 - learning_rate: 1.0000e-05
# Epoch 42/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8741 - loss: 0.7642 - val_accuracy: 0.7737 - val_loss: 1.0874 - learning_rate: 1.0000e-05
# Epoch 43/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8651 - loss: 0.7678 - val_accuracy: 0.7742 - val_loss: 1.0847 - learning_rate: 1.0000e-05
# Epoch 44/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8761 - loss: 0.7465 - val_accuracy: 0.7751 - val_loss: 1.0852 - learning_rate: 1.0000e-05
# Epoch 45/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8743 - loss: 0.7534 - val_accuracy: 0.7755 - val_loss: 1.0792 - learning_rate: 1.0000e-05
# Epoch 46/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8766 - loss: 0.7461 - val_accuracy: 0.7736 - val_loss: 1.0842 - learning_rate: 1.0000e-05
# Epoch 47/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8768 - loss: 0.7513 - val_accuracy: 0.7750 - val_loss: 1.0819 - learning_rate: 1.0000e-05
# Epoch 48/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8706 - loss: 0.7515 - val_accuracy: 0.7748 - val_loss: 1.0845 - learning_rate: 1.0000e-05
# Epoch 49/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8693 - loss: 0.7608 - val_accuracy: 0.7756 - val_loss: 1.0782 - learning_rate: 1.0000e-05
# Epoch 50/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8780 - loss: 0.7348 - val_accuracy: 0.7747 - val_loss: 1.0813 - learning_rate: 1.0000e-05
# Epoch 51/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8733 - loss: 0.7440 - val_accuracy: 0.7756 - val_loss: 1.0781 - learning_rate: 1.0000e-05
# Epoch 52/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8744 - loss: 0.7413 - val_accuracy: 0.7739 - val_loss: 1.0772 - learning_rate: 1.0000e-05
# Epoch 53/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8812 - loss: 0.7312 - val_accuracy: 0.7727 - val_loss: 1.0839 - learning_rate: 1.0000e-05
# Epoch 54/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8779 - loss: 0.7274 - val_accuracy: 0.7741 - val_loss: 1.0815 - learning_rate: 1.0000e-05
# Epoch 55/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8797 - loss: 0.7192 - val_accuracy: 0.7753 - val_loss: 1.0748 - learning_rate: 1.0000e-05
# Epoch 56/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8789 - loss: 0.7298 - val_accuracy: 0.7737 - val_loss: 1.0745 - learning_rate: 1.0000e-05
# Epoch 57/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8839 - loss: 0.7207 - val_accuracy: 0.7772 - val_loss: 1.0674 - learning_rate: 1.0000e-05
# Epoch 58/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8806 - loss: 0.7277 - val_accuracy: 0.7744 - val_loss: 1.0710 - learning_rate: 1.0000e-05
# Epoch 59/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8700 - loss: 0.7300 - val_accuracy: 0.7761 - val_loss: 1.0659 - learning_rate: 1.0000e-05
# Epoch 60/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8729 - loss: 0.7322 - val_accuracy: 0.7749 - val_loss: 1.0726 - learning_rate: 1.0000e-05
# Epoch 61/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8803 - loss: 0.7242 - val_accuracy: 0.7767 - val_loss: 1.0662 - learning_rate: 1.0000e-05
# Epoch 62/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8822 - loss: 0.7128 - val_accuracy: 0.7732 - val_loss: 1.0727 - learning_rate: 1.0000e-05
# Epoch 63/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8784 - loss: 0.7236 - val_accuracy: 0.7717 - val_loss: 1.0752 - learning_rate: 1.0000e-05
# Epoch 64/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8834 - loss: 0.7085 - val_accuracy: 0.7737 - val_loss: 1.0715 - learning_rate: 1.0000e-05
# Epoch 65/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8735 - loss: 0.7217 - val_accuracy: 0.7757 - val_loss: 1.0644 - learning_rate: 1.0000e-05
# Epoch 66/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.8796 - loss: 0.7082 - val_accuracy: 0.7731 - val_loss: 1.0694 - learning_rate: 1.0000e-05
# Epoch 67/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.8821 - loss: 0.7141 - val_accuracy: 0.7781 - val_loss: 1.0596 - learning_rate: 1.0000e-05
# Epoch 68/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.8818 - loss: 0.7161 - val_accuracy: 0.7719 - val_loss: 1.0702 - learning_rate: 1.0000e-05
# Epoch 69/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8814 - loss: 0.7118 - val_accuracy: 0.7760 - val_loss: 1.0599 - learning_rate: 1.0000e-05
# Epoch 70/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8739 - loss: 0.7201 - val_accuracy: 0.7786 - val_loss: 1.0575 - learning_rate: 1.0000e-05
# Epoch 71/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8832 - loss: 0.7129 - val_accuracy: 0.7740 - val_loss: 1.0647 - learning_rate: 1.0000e-05
# Epoch 72/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8832 - loss: 0.6911 - val_accuracy: 0.7739 - val_loss: 1.0652 - learning_rate: 1.0000e-05
# Epoch 73/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8863 - loss: 0.6968 - val_accuracy: 0.7751 - val_loss: 1.0623 - learning_rate: 1.0000e-05
# Epoch 74/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8870 - loss: 0.6888 - val_accuracy: 0.7781 - val_loss: 1.0526 - learning_rate: 1.0000e-05
# Epoch 75/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8846 - loss: 0.6987 - val_accuracy: 0.7752 - val_loss: 1.0617 - learning_rate: 1.0000e-05
# Epoch 76/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8786 - loss: 0.7013 - val_accuracy: 0.7770 - val_loss: 1.0532 - learning_rate: 1.0000e-05
# Epoch 77/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8866 - loss: 0.6812 - val_accuracy: 0.7766 - val_loss: 1.0554 - learning_rate: 1.0000e-05
# Epoch 78/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8835 - loss: 0.6948 - val_accuracy: 0.7755 - val_loss: 1.0594 - learning_rate: 1.0000e-05
# Epoch 79/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8803 - loss: 0.7000 - val_accuracy: 0.7759 - val_loss: 1.0557 - learning_rate: 1.0000e-05
# Epoch 80/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8904 - loss: 0.6775 - val_accuracy: 0.7783 - val_loss: 1.0480 - learning_rate: 1.0000e-05
# Epoch 81/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.8823 - loss: 0.6873 - val_accuracy: 0.7770 - val_loss: 1.0481 - learning_rate: 1.0000e-05
# Epoch 82/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.8814 - loss: 0.6846 - val_accuracy: 0.7762 - val_loss: 1.0524 - learning_rate: 1.0000e-05
# Epoch 83/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8866 - loss: 0.6733 - val_accuracy: 0.7750 - val_loss: 1.0511 - learning_rate: 1.0000e-05
# Epoch 84/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8921 - loss: 0.6686 - val_accuracy: 0.7738 - val_loss: 1.0576 - learning_rate: 1.0000e-05
# Epoch 85/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.8880 - loss: 0.6723 - val_accuracy: 0.7752 - val_loss: 1.0500 - learning_rate: 1.0000e-05
# Epoch 86/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8861 - loss: 0.6704 - val_accuracy: 0.7764 - val_loss: 1.0439 - learning_rate: 1.0000e-05
# Epoch 87/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8875 - loss: 0.6736 - val_accuracy: 0.7763 - val_loss: 1.0521 - learning_rate: 1.0000e-05
# Epoch 88/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8835 - loss: 0.6735 - val_accuracy: 0.7751 - val_loss: 1.0481 - learning_rate: 1.0000e-05
# Epoch 89/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8938 - loss: 0.6684 - val_accuracy: 0.7762 - val_loss: 1.0434 - learning_rate: 1.0000e-05
# Epoch 90/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8885 - loss: 0.6623 - val_accuracy: 0.7770 - val_loss: 1.0455 - learning_rate: 1.0000e-05
# Epoch 91/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8976 - loss: 0.6545 - val_accuracy: 0.7762 - val_loss: 1.0456 - learning_rate: 1.0000e-05
# Epoch 92/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8932 - loss: 0.6645 - val_accuracy: 0.7748 - val_loss: 1.0521 - learning_rate: 1.0000e-05
# Epoch 93/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8964 - loss: 0.6679 - val_accuracy: 0.7762 - val_loss: 1.0446 - learning_rate: 1.0000e-05
# Epoch 94/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8879 - loss: 0.6633 - val_accuracy: 0.7748 - val_loss: 1.0501 - learning_rate: 1.0000e-05
# Epoch 95/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8928 - loss: 0.6642 - val_accuracy: 0.7772 - val_loss: 1.0413 - learning_rate: 1.0000e-05
# Epoch 96/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8915 - loss: 0.6675 - val_accuracy: 0.7765 - val_loss: 1.0439 - learning_rate: 1.0000e-05
# Epoch 97/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9004 - loss: 0.6434 - val_accuracy: 0.7735 - val_loss: 1.0531 - learning_rate: 1.0000e-05
# Epoch 98/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8873 - loss: 0.6625 - val_accuracy: 0.7756 - val_loss: 1.0422 - learning_rate: 1.0000e-05
# Epoch 99/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8959 - loss: 0.6482 - val_accuracy: 0.7756 - val_loss: 1.0384 - learning_rate: 1.0000e-05
# Epoch 100/100
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.8938 - loss: 0.6427 - val_accuracy: 0.7768 - val_loss: 1.0442 - learning_rate: 1.0000e-05

# %%
#Saving the model
model.save('Primeiro_treino.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow import keras

model = keras.models.load_model('Primeiro_treino.h5')
# Validacao da Rede
val_loss, val_acc = model.evaluate(validation_dataset)
print('val_acc:', val_acc)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 417/417 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7777 - loss: 1.0445
# val_acc: 0.775600016117096

# %%
import matplotlib.pyplot as plt


# Extraindo os valores de acurácia e perda do histórico de treinamento
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Definindo o número de épocas
epochs = range(1, len(acc) + 1)

# Plotando a acurácia de treinamento e validação
plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

# Exibindo o gráfico de acurácia
plt.figure()

# Plotando a perda de treinamento e validação
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

# Exibindo o gráfico de perda
plt.show()
