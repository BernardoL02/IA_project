# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import image_dataset_from_directory
import os

base_dir = 'Imagens/'

# Diretórios para treino, validação e teste
train_dir = os.path.join(base_dir, 'train/train2/')
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

# %%
IMG_SIZE = 96
BATCH_SIZE = 32

# Configuração do gerador de imagens sem data augmentation
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_dataset = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)

validation_dataset = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)

test_dataset = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


num_classes = 10

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(96, 96, 3),kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(256, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.00001)

# %%
# Treinar Rede
#model.load_weights('Primeiro_treino.h5')
history = model.fit(train_dataset, epochs=100, validation_data=validation_dataset, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 136ms/step - accuracy: 0.2390 - loss: 4.0642 - val_accuracy: 0.1024 - val_loss: 5.8595 - learning_rate: 0.0010
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 137ms/step - accuracy: 0.3550 - loss: 3.2243 - val_accuracy: 0.2550 - val_loss: 3.5862 - learning_rate: 0.0010
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.4202 - loss: 2.8153 - val_accuracy: 0.4018 - val_loss: 2.9474 - learning_rate: 0.0010
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 50s 158ms/step - accuracy: 0.4770 - loss: 2.5825 - val_accuracy: 0.3965 - val_loss: 2.8654 - learning_rate: 0.0010
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 58s 184ms/step - accuracy: 0.5075 - loss: 2.3795 - val_accuracy: 0.2560 - val_loss: 3.9479 - learning_rate: 0.0010
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.5593 - loss: 2.1957 - val_accuracy: 0.5208 - val_loss: 2.3737 - learning_rate: 0.0010
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 54s 173ms/step - accuracy: 0.5919 - loss: 2.0738 - val_accuracy: 0.5331 - val_loss: 2.1969 - learning_rate: 0.0010
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 60s 193ms/step - accuracy: 0.6148 - loss: 1.9796 - val_accuracy: 0.5688 - val_loss: 2.1365 - learning_rate: 0.0010
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 74s 168ms/step - accuracy: 0.6236 - loss: 1.9506 - val_accuracy: 0.5851 - val_loss: 2.1202 - learning_rate: 0.0010
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 143ms/step - accuracy: 0.6365 - loss: 1.9376 - val_accuracy: 0.5808 - val_loss: 2.1371 - learning_rate: 0.0010
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 145ms/step - accuracy: 0.6496 - loss: 1.9283 - val_accuracy: 0.6783 - val_loss: 1.8822 - learning_rate: 0.0010
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.6706 - loss: 1.9037 - val_accuracy: 0.6440 - val_loss: 2.0263 - learning_rate: 0.0010
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 63s 200ms/step - accuracy: 0.6872 - loss: 1.9244 - val_accuracy: 0.6793 - val_loss: 1.9456 - learning_rate: 0.0010
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 129ms/step - accuracy: 0.6849 - loss: 1.9383 - val_accuracy: 0.6676 - val_loss: 1.9930 - learning_rate: 0.0010
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - accuracy: 0.6902 - loss: 1.9477 - val_accuracy: 0.6470 - val_loss: 2.1347 - learning_rate: 0.0010
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 57s 182ms/step - accuracy: 0.7016 - loss: 1.9650 - val_accuracy: 0.6438 - val_loss: 2.1583 - learning_rate: 0.0010
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 68s 217ms/step - accuracy: 0.7373 - loss: 1.8637 - val_accuracy: 0.7330 - val_loss: 1.8321 - learning_rate: 1.0000e-04
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 68s 216ms/step - accuracy: 0.7637 - loss: 1.7465 - val_accuracy: 0.7410 - val_loss: 1.7757 - learning_rate: 1.0000e-04
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 68s 215ms/step - accuracy: 0.7825 - loss: 1.6423 - val_accuracy: 0.7452 - val_loss: 1.7141 - learning_rate: 1.0000e-04
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 51s 163ms/step - accuracy: 0.7889 - loss: 1.5800 - val_accuracy: 0.7548 - val_loss: 1.6577 - learning_rate: 1.0000e-04
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 55s 176ms/step - accuracy: 0.7873 - loss: 1.5278 - val_accuracy: 0.7597 - val_loss: 1.6076 - learning_rate: 1.0000e-04
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 68s 217ms/step - accuracy: 0.8083 - loss: 1.4450 - val_accuracy: 0.7647 - val_loss: 1.5607 - learning_rate: 1.0000e-04
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 59s 187ms/step - accuracy: 0.8262 - loss: 1.3721 - val_accuracy: 0.7614 - val_loss: 1.5441 - learning_rate: 1.0000e-04
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.8210 - loss: 1.3411 - val_accuracy: 0.7601 - val_loss: 1.5397 - learning_rate: 1.0000e-04
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.8372 - loss: 1.2838 - val_accuracy: 0.7704 - val_loss: 1.4656 - learning_rate: 1.0000e-04
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 126ms/step - accuracy: 0.8375 - loss: 1.2487 - val_accuracy: 0.7745 - val_loss: 1.4415 - learning_rate: 1.0000e-04
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.8483 - loss: 1.2010 - val_accuracy: 0.7692 - val_loss: 1.4360 - learning_rate: 1.0000e-04
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 123ms/step - accuracy: 0.8555 - loss: 1.1512 - val_accuracy: 0.7727 - val_loss: 1.4029 - learning_rate: 1.0000e-04
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.8519 - loss: 1.1353 - val_accuracy: 0.7681 - val_loss: 1.4045 - learning_rate: 1.0000e-04
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 125ms/step - accuracy: 0.8658 - loss: 1.0833 - val_accuracy: 0.7716 - val_loss: 1.3692 - learning_rate: 1.0000e-04
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.8693 - loss: 1.0570 - val_accuracy: 0.7693 - val_loss: 1.3691 - learning_rate: 1.0000e-04
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.8746 - loss: 1.0257 - val_accuracy: 0.7754 - val_loss: 1.3425 - learning_rate: 1.0000e-04
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.8729 - loss: 1.0086 - val_accuracy: 0.7713 - val_loss: 1.3484 - learning_rate: 1.0000e-04
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 125ms/step - accuracy: 0.8870 - loss: 0.9658 - val_accuracy: 0.7816 - val_loss: 1.2963 - learning_rate: 1.0000e-04
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.8897 - loss: 0.9387 - val_accuracy: 0.7805 - val_loss: 1.2931 - learning_rate: 1.0000e-04
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.8907 - loss: 0.9341 - val_accuracy: 0.7814 - val_loss: 1.2871 - learning_rate: 1.0000e-04
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.8902 - loss: 0.9182 - val_accuracy: 0.7848 - val_loss: 1.2650 - learning_rate: 1.0000e-04
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.8942 - loss: 0.8856 - val_accuracy: 0.7804 - val_loss: 1.2718 - learning_rate: 1.0000e-04
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.8940 - loss: 0.8813 - val_accuracy: 0.7822 - val_loss: 1.2576 - learning_rate: 1.0000e-04
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.8958 - loss: 0.8669 - val_accuracy: 0.7800 - val_loss: 1.2565 - learning_rate: 1.0000e-04
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 61s 194ms/step - accuracy: 0.9045 - loss: 0.8360 - val_accuracy: 0.7763 - val_loss: 1.2585 - learning_rate: 1.0000e-04
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 68s 217ms/step - accuracy: 0.8984 - loss: 0.8397 - val_accuracy: 0.7875 - val_loss: 1.2242 - learning_rate: 1.0000e-04
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 68s 216ms/step - accuracy: 0.9103 - loss: 0.8074 - val_accuracy: 0.7801 - val_loss: 1.2308 - learning_rate: 1.0000e-04
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.9080 - loss: 0.8015 - val_accuracy: 0.7789 - val_loss: 1.2387 - learning_rate: 1.0000e-04
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.9086 - loss: 0.7945 - val_accuracy: 0.7782 - val_loss: 1.2359 - learning_rate: 1.0000e-04
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 49s 156ms/step - accuracy: 0.9142 - loss: 0.7743 - val_accuracy: 0.7809 - val_loss: 1.2348 - learning_rate: 1.0000e-04
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 68s 217ms/step - accuracy: 0.9153 - loss: 0.7543 - val_accuracy: 0.7830 - val_loss: 1.2197 - learning_rate: 1.0000e-04
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 49s 157ms/step - accuracy: 0.9224 - loss: 0.7456 - val_accuracy: 0.7800 - val_loss: 1.2182 - learning_rate: 1.0000e-04
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 143ms/step - accuracy: 0.9196 - loss: 0.7412 - val_accuracy: 0.7818 - val_loss: 1.2263 - learning_rate: 1.0000e-04
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9190 - loss: 0.7227 - val_accuracy: 0.7796 - val_loss: 1.2133 - learning_rate: 1.0000e-04
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9158 - loss: 0.7259 - val_accuracy: 0.7783 - val_loss: 1.2249 - learning_rate: 1.0000e-04
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9223 - loss: 0.7070 - val_accuracy: 0.7795 - val_loss: 1.2074 - learning_rate: 1.0000e-04
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9239 - loss: 0.6990 - val_accuracy: 0.7810 - val_loss: 1.2021 - learning_rate: 1.0000e-04
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9337 - loss: 0.6765 - val_accuracy: 0.7838 - val_loss: 1.1813 - learning_rate: 1.0000e-04
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 137ms/step - accuracy: 0.9250 - loss: 0.6814 - val_accuracy: 0.7793 - val_loss: 1.1976 - learning_rate: 1.0000e-04
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9301 - loss: 0.6737 - val_accuracy: 0.7843 - val_loss: 1.1855 - learning_rate: 1.0000e-04
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9300 - loss: 0.6622 - val_accuracy: 0.7830 - val_loss: 1.2022 - learning_rate: 1.0000e-04
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 137ms/step - accuracy: 0.9362 - loss: 0.6413 - val_accuracy: 0.7858 - val_loss: 1.1859 - learning_rate: 1.0000e-04
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 138ms/step - accuracy: 0.9353 - loss: 0.6561 - val_accuracy: 0.7836 - val_loss: 1.1970 - learning_rate: 1.0000e-04
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 140ms/step - accuracy: 0.9303 - loss: 0.6520 - val_accuracy: 0.7860 - val_loss: 1.1810 - learning_rate: 1.0000e-05
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 137ms/step - accuracy: 0.9399 - loss: 0.6250 - val_accuracy: 0.7866 - val_loss: 1.1808 - learning_rate: 1.0000e-05
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 138ms/step - accuracy: 0.9431 - loss: 0.6239 - val_accuracy: 0.7887 - val_loss: 1.1726 - learning_rate: 1.0000e-05
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 139ms/step - accuracy: 0.9416 - loss: 0.6176 - val_accuracy: 0.7898 - val_loss: 1.1711 - learning_rate: 1.0000e-05
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 140ms/step - accuracy: 0.9429 - loss: 0.6139 - val_accuracy: 0.7887 - val_loss: 1.1675 - learning_rate: 1.0000e-05
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 144ms/step - accuracy: 0.9416 - loss: 0.6122 - val_accuracy: 0.7898 - val_loss: 1.1653 - learning_rate: 1.0000e-05
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 144ms/step - accuracy: 0.9460 - loss: 0.6112 - val_accuracy: 0.7910 - val_loss: 1.1662 - learning_rate: 1.0000e-05
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 145ms/step - accuracy: 0.9487 - loss: 0.6059 - val_accuracy: 0.7886 - val_loss: 1.1683 - learning_rate: 1.0000e-05
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 142ms/step - accuracy: 0.9489 - loss: 0.5990 - val_accuracy: 0.7920 - val_loss: 1.1592 - learning_rate: 1.0000e-05
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 142ms/step - accuracy: 0.9453 - loss: 0.6028 - val_accuracy: 0.7923 - val_loss: 1.1611 - learning_rate: 1.0000e-05
# Epoch 70/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 46s 145ms/step - accuracy: 0.9512 - loss: 0.5844 - val_accuracy: 0.7930 - val_loss: 1.1604 - learning_rate: 1.0000e-05
# Epoch 71/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 143ms/step - accuracy: 0.9535 - loss: 0.5807 - val_accuracy: 0.7922 - val_loss: 1.1630 - learning_rate: 1.0000e-05
# Epoch 72/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 145ms/step - accuracy: 0.9398 - loss: 0.6079 - val_accuracy: 0.7907 - val_loss: 1.1636 - learning_rate: 1.0000e-05
# Epoch 73/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 46s 145ms/step - accuracy: 0.9457 - loss: 0.5918 - val_accuracy: 0.7926 - val_loss: 1.1593 - learning_rate: 1.0000e-05
# Epoch 74/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 140ms/step - accuracy: 0.9510 - loss: 0.5949 - val_accuracy: 0.7907 - val_loss: 1.1597 - learning_rate: 1.0000e-05
# Epoch 75/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 141ms/step - accuracy: 0.9503 - loss: 0.5854 - val_accuracy: 0.7930 - val_loss: 1.1558 - learning_rate: 1.0000e-05
# Epoch 76/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 141ms/step - accuracy: 0.9506 - loss: 0.5887 - val_accuracy: 0.7915 - val_loss: 1.1581 - learning_rate: 1.0000e-05
# Epoch 77/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 141ms/step - accuracy: 0.9494 - loss: 0.5837 - val_accuracy: 0.7909 - val_loss: 1.1613 - learning_rate: 1.0000e-05
# Epoch 78/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 144ms/step - accuracy: 0.9541 - loss: 0.5786 - val_accuracy: 0.7916 - val_loss: 1.1592 - learning_rate: 1.0000e-05
# Epoch 79/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 142ms/step - accuracy: 0.9501 - loss: 0.5829 - val_accuracy: 0.7931 - val_loss: 1.1566 - learning_rate: 1.0000e-05
# Epoch 80/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 140ms/step - accuracy: 0.9552 - loss: 0.5739 - val_accuracy: 0.7930 - val_loss: 1.1510 - learning_rate: 1.0000e-05
# Epoch 81/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 142ms/step - accuracy: 0.9543 - loss: 0.5630 - val_accuracy: 0.7925 - val_loss: 1.1572 - learning_rate: 1.0000e-05
# Epoch 82/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 141ms/step - accuracy: 0.9553 - loss: 0.5675 - val_accuracy: 0.7904 - val_loss: 1.1628 - learning_rate: 1.0000e-05
# Epoch 83/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 54s 172ms/step - accuracy: 0.9514 - loss: 0.5710 - val_accuracy: 0.7910 - val_loss: 1.1600 - learning_rate: 1.0000e-05
# Epoch 84/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 61s 195ms/step - accuracy: 0.9519 - loss: 0.5701 - val_accuracy: 0.7928 - val_loss: 1.1567 - learning_rate: 1.0000e-05
# Epoch 85/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 65s 208ms/step - accuracy: 0.9561 - loss: 0.5638 - val_accuracy: 0.7921 - val_loss: 1.1539 - learning_rate: 1.0000e-05
# Epoch 86/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 68s 218ms/step - accuracy: 0.9527 - loss: 0.5712 - val_accuracy: 0.7908 - val_loss: 1.1588 - learning_rate: 1.0000e-05
# Epoch 87/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 49s 155ms/step - accuracy: 0.9518 - loss: 0.5691 - val_accuracy: 0.7911 - val_loss: 1.1578 - learning_rate: 1.0000e-05
# Epoch 88/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 138ms/step - accuracy: 0.9566 - loss: 0.5575 - val_accuracy: 0.7901 - val_loss: 1.1573 - learning_rate: 1.0000e-05
# Epoch 89/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 137ms/step - accuracy: 0.9529 - loss: 0.5665 - val_accuracy: 0.7921 - val_loss: 1.1499 - learning_rate: 1.0000e-05
# Epoch 90/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 142ms/step - accuracy: 0.9538 - loss: 0.5571 - val_accuracy: 0.7898 - val_loss: 1.1560 - learning_rate: 1.0000e-05
# Epoch 91/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 139ms/step - accuracy: 0.9514 - loss: 0.5675 - val_accuracy: 0.7926 - val_loss: 1.1495 - learning_rate: 1.0000e-05
# Epoch 92/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 135ms/step - accuracy: 0.9571 - loss: 0.5542 - val_accuracy: 0.7920 - val_loss: 1.1466 - learning_rate: 1.0000e-05
# Epoch 93/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 135ms/step - accuracy: 0.9549 - loss: 0.5530 - val_accuracy: 0.7928 - val_loss: 1.1500 - learning_rate: 1.0000e-05
# Epoch 94/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.9567 - loss: 0.5486 - val_accuracy: 0.7931 - val_loss: 1.1489 - learning_rate: 1.0000e-05
# Epoch 95/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.9524 - loss: 0.5651 - val_accuracy: 0.7920 - val_loss: 1.1486 - learning_rate: 1.0000e-05
# Epoch 96/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 133ms/step - accuracy: 0.9580 - loss: 0.5485 - val_accuracy: 0.7921 - val_loss: 1.1490 - learning_rate: 1.0000e-05
# Epoch 97/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.9541 - loss: 0.5544 - val_accuracy: 0.7900 - val_loss: 1.1514 - learning_rate: 1.0000e-05
# Epoch 98/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.9506 - loss: 0.5619 - val_accuracy: 0.7917 - val_loss: 1.1508 - learning_rate: 1.0000e-05
# Epoch 99/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.9545 - loss: 0.5501 - val_accuracy: 0.7942 - val_loss: 1.1419 - learning_rate: 1.0000e-05
# Epoch 100/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.9609 - loss: 0.5349 - val_accuracy: 0.7924 - val_loss: 1.1469 - learning_rate: 1.0000e-05

# %%
#Saving the model
model.save('Primeiro_treino.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow import keras

model = keras.models.load_model('Primeiro_treino.h5')
# Validacao da Rede
val_loss, val_acc = model.evaluate(validation_dataset)
print('val_acc:', val_acc)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7889 - loss: 1.1625
# val_acc: 0.7942000031471252

# %%
import matplotlib.pyplot as plt


# Extraindo os valores de acurácia e perda do histórico de treinamento
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Definindo o número de épocas
epochs = range(1, len(acc) + 1)

# Plotando a acurácia de treinamento e validação
plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

# Exibindo o gráfico de acurácia
plt.figure()

# Plotando a perda de treinamento e validação
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

# Exibindo o gráfico de perda
plt.show()
