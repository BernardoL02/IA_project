# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import image_dataset_from_directory
import os

base_dir = 'Imagens/'

# Diretórios para treino, validação e teste
train_dir = os.path.join(base_dir, 'train/train3/')
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

# %%
IMG_SIZE = 32
BATCH_SIZE = 32

# Configuração do gerador de imagens sem data augmentation
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_dataset = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)

validation_dataset = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)

test_dataset = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


num_classes = 10

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3),kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.00001)

# %%
# Treinar Rede
model.load_weights('Primeiro_treino.h5')
history = model.fit(train_dataset, epochs=100, validation_data=validation_dataset, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
#   1/313 ━━━━━━━━━━━━━━━━━━━━ 10:15 2s/step - accuracy: 0.6562 - loss: 1.5840
# c:\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.6099 - loss: 1.6153 - val_accuracy: 0.6233 - val_loss: 1.6053 - learning_rate: 0.0010
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.6441 - loss: 1.5478 - val_accuracy: 0.6180 - val_loss: 1.6550 - learning_rate: 0.0010
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.6548 - loss: 1.5720 - val_accuracy: 0.5618 - val_loss: 1.8992 - learning_rate: 0.0010
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.6659 - loss: 1.5785 - val_accuracy: 0.6776 - val_loss: 1.5900 - learning_rate: 0.0010
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.6572 - loss: 1.6245 - val_accuracy: 0.6507 - val_loss: 1.7163 - learning_rate: 0.0010
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.6673 - loss: 1.6219 - val_accuracy: 0.5916 - val_loss: 1.8859 - learning_rate: 0.0010
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.6820 - loss: 1.6354 - val_accuracy: 0.6243 - val_loss: 1.8230 - learning_rate: 0.0010
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.6866 - loss: 1.6335 - val_accuracy: 0.6358 - val_loss: 1.7826 - learning_rate: 0.0010
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.6794 - loss: 1.6583 - val_accuracy: 0.5787 - val_loss: 2.0222 - learning_rate: 0.0010
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.7200 - loss: 1.5514 - val_accuracy: 0.7360 - val_loss: 1.4882 - learning_rate: 1.0000e-04
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7324 - loss: 1.4989 - val_accuracy: 0.7437 - val_loss: 1.4485 - learning_rate: 1.0000e-04
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7334 - loss: 1.4573 - val_accuracy: 0.7472 - val_loss: 1.4176 - learning_rate: 1.0000e-04
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7484 - loss: 1.4179 - val_accuracy: 0.7414 - val_loss: 1.4100 - learning_rate: 1.0000e-04
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.7542 - loss: 1.3735 - val_accuracy: 0.7454 - val_loss: 1.3807 - learning_rate: 1.0000e-04
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.7500 - loss: 1.3352 - val_accuracy: 0.7534 - val_loss: 1.3512 - learning_rate: 1.0000e-04
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7619 - loss: 1.2988 - val_accuracy: 0.7596 - val_loss: 1.3175 - learning_rate: 1.0000e-04
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7623 - loss: 1.2806 - val_accuracy: 0.7439 - val_loss: 1.3449 - learning_rate: 1.0000e-04
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7717 - loss: 1.2524 - val_accuracy: 0.7556 - val_loss: 1.2980 - learning_rate: 1.0000e-04
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7766 - loss: 1.2117 - val_accuracy: 0.7376 - val_loss: 1.3406 - learning_rate: 1.0000e-04
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7782 - loss: 1.1854 - val_accuracy: 0.7430 - val_loss: 1.3072 - learning_rate: 1.0000e-04
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.7658 - loss: 1.2078 - val_accuracy: 0.7514 - val_loss: 1.2790 - learning_rate: 1.0000e-04
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.7847 - loss: 1.1585 - val_accuracy: 0.7299 - val_loss: 1.3356 - learning_rate: 1.0000e-04
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7849 - loss: 1.1643 - val_accuracy: 0.7609 - val_loss: 1.2243 - learning_rate: 1.0000e-04
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7804 - loss: 1.1311 - val_accuracy: 0.7551 - val_loss: 1.2271 - learning_rate: 1.0000e-04
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7893 - loss: 1.1152 - val_accuracy: 0.7569 - val_loss: 1.2087 - learning_rate: 1.0000e-04
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.7849 - loss: 1.0979 - val_accuracy: 0.7631 - val_loss: 1.1856 - learning_rate: 1.0000e-04
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7994 - loss: 1.0584 - val_accuracy: 0.7695 - val_loss: 1.1619 - learning_rate: 1.0000e-04
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.8036 - loss: 1.0446 - val_accuracy: 0.7667 - val_loss: 1.1575 - learning_rate: 1.0000e-04
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8068 - loss: 1.0309 - val_accuracy: 0.7614 - val_loss: 1.1676 - learning_rate: 1.0000e-04
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8043 - loss: 1.0182 - val_accuracy: 0.7608 - val_loss: 1.1596 - learning_rate: 1.0000e-04
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.7985 - loss: 1.0371 - val_accuracy: 0.7562 - val_loss: 1.1717 - learning_rate: 1.0000e-04
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.8121 - loss: 0.9992 - val_accuracy: 0.7626 - val_loss: 1.1486 - learning_rate: 1.0000e-04
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8207 - loss: 0.9590 - val_accuracy: 0.7512 - val_loss: 1.1747 - learning_rate: 1.0000e-04
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.8177 - loss: 0.9603 - val_accuracy: 0.7577 - val_loss: 1.1495 - learning_rate: 1.0000e-04
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.8139 - loss: 0.9707 - val_accuracy: 0.7620 - val_loss: 1.1256 - learning_rate: 1.0000e-04
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8236 - loss: 0.9517 - val_accuracy: 0.7664 - val_loss: 1.1059 - learning_rate: 1.0000e-04
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8248 - loss: 0.9349 - val_accuracy: 0.7711 - val_loss: 1.0937 - learning_rate: 1.0000e-04
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8177 - loss: 0.9420 - val_accuracy: 0.7636 - val_loss: 1.1091 - learning_rate: 1.0000e-04
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8263 - loss: 0.9212 - val_accuracy: 0.7494 - val_loss: 1.1662 - learning_rate: 1.0000e-04
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8268 - loss: 0.9126 - val_accuracy: 0.7498 - val_loss: 1.1492 - learning_rate: 1.0000e-04
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8315 - loss: 0.8931 - val_accuracy: 0.7657 - val_loss: 1.0924 - learning_rate: 1.0000e-04
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8282 - loss: 0.8876 - val_accuracy: 0.7592 - val_loss: 1.1093 - learning_rate: 1.0000e-04
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8296 - loss: 0.8882 - val_accuracy: 0.7560 - val_loss: 1.1175 - learning_rate: 1.0000e-04
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.8380 - loss: 0.8574 - val_accuracy: 0.7472 - val_loss: 1.1461 - learning_rate: 1.0000e-04
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.8318 - loss: 0.8722 - val_accuracy: 0.7605 - val_loss: 1.0961 - learning_rate: 1.0000e-04
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8396 - loss: 0.8427 - val_accuracy: 0.7604 - val_loss: 1.1019 - learning_rate: 1.0000e-04
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8396 - loss: 0.8455 - val_accuracy: 0.7641 - val_loss: 1.0957 - learning_rate: 1.0000e-05
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8391 - loss: 0.8377 - val_accuracy: 0.7632 - val_loss: 1.0946 - learning_rate: 1.0000e-05
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8388 - loss: 0.8297 - val_accuracy: 0.7640 - val_loss: 1.0858 - learning_rate: 1.0000e-05
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8423 - loss: 0.8388 - val_accuracy: 0.7652 - val_loss: 1.0894 - learning_rate: 1.0000e-05
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8413 - loss: 0.8301 - val_accuracy: 0.7636 - val_loss: 1.0891 - learning_rate: 1.0000e-05
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8425 - loss: 0.8256 - val_accuracy: 0.7646 - val_loss: 1.0898 - learning_rate: 1.0000e-05
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8407 - loss: 0.8267 - val_accuracy: 0.7617 - val_loss: 1.0990 - learning_rate: 1.0000e-05
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8446 - loss: 0.8222 - val_accuracy: 0.7685 - val_loss: 1.0772 - learning_rate: 1.0000e-05
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8385 - loss: 0.8223 - val_accuracy: 0.7658 - val_loss: 1.0811 - learning_rate: 1.0000e-05
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8473 - loss: 0.7996 - val_accuracy: 0.7651 - val_loss: 1.0792 - learning_rate: 1.0000e-05
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8426 - loss: 0.8190 - val_accuracy: 0.7671 - val_loss: 1.0763 - learning_rate: 1.0000e-05
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8469 - loss: 0.8172 - val_accuracy: 0.7671 - val_loss: 1.0774 - learning_rate: 1.0000e-05
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8517 - loss: 0.7976 - val_accuracy: 0.7674 - val_loss: 1.0714 - learning_rate: 1.0000e-05
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8425 - loss: 0.8097 - val_accuracy: 0.7640 - val_loss: 1.0840 - learning_rate: 1.0000e-05
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8346 - loss: 0.8214 - val_accuracy: 0.7673 - val_loss: 1.0764 - learning_rate: 1.0000e-05
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8439 - loss: 0.8108 - val_accuracy: 0.7660 - val_loss: 1.0760 - learning_rate: 1.0000e-05
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.8571 - loss: 0.7851 - val_accuracy: 0.7644 - val_loss: 1.0792 - learning_rate: 1.0000e-05
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.8505 - loss: 0.7961 - val_accuracy: 0.7635 - val_loss: 1.0808 - learning_rate: 1.0000e-05
# Epoch 65/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.8588 - loss: 0.7883 - val_accuracy: 0.7658 - val_loss: 1.0746 - learning_rate: 1.0000e-05
# Epoch 66/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.8457 - loss: 0.8228 - val_accuracy: 0.7614 - val_loss: 1.0864 - learning_rate: 1.0000e-05
# Epoch 67/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.8423 - loss: 0.8121 - val_accuracy: 0.7663 - val_loss: 1.0732 - learning_rate: 1.0000e-05
# Epoch 68/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.8560 - loss: 0.7840 - val_accuracy: 0.7656 - val_loss: 1.0806 - learning_rate: 1.0000e-05
# Epoch 69/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8439 - loss: 0.8137 - val_accuracy: 0.7652 - val_loss: 1.0775 - learning_rate: 1.0000e-05

# %%
#Saving the model
model.save('Primeiro_treino.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow import keras

model = keras.models.load_model('Primeiro_treino.h5')
# Validacao da Rede
val_loss, val_acc = model.evaluate(validation_dataset)
print('val_acc:', val_acc)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7659 - loss: 1.0692
# val_acc: 0.7674000263214111

# %%
import matplotlib.pyplot as plt


# Extraindo os valores de acurácia e perda do histórico de treinamento
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Definindo o número de épocas
epochs = range(1, len(acc) + 1)

# Plotando a acurácia de treinamento e validação
plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

# Exibindo o gráfico de acurácia
plt.figure()

# Plotando a perda de treinamento e validação
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

# Exibindo o gráfico de perda
plt.show()
