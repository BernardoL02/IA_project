# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import image_dataset_from_directory
import os

base_dir = 'Imagens/'

# Diretórios para treino, validação e teste
train_dir = os.path.join(base_dir, 'train/train1/')
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

# %%
IMG_SIZE = 32
BATCH_SIZE =24

# Configuração do gerador de imagens sem data augmentation
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_dataset = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)

validation_dataset = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)

test_dataset = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    
)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam


num_classes = 10

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3),kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\Tex\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Tex\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From c:\Users\Tex\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.00001)

# %%
# Treinar Rede
model.load_weights('Primeiro_treino.h5')
history = model.fit(train_dataset, epochs=100, validation_data=validation_dataset, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\Tex\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Tex\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 417/417 [==============================] - 13s 28ms/step - loss: 1.5824 - accuracy: 0.6397 - val_loss: 1.4982 - val_accuracy: 0.6695 - lr: 0.0010
# Epoch 2/100
# 417/417 [==============================] - 9s 21ms/step - loss: 1.5685 - accuracy: 0.6646 - val_loss: 1.5993 - val_accuracy: 0.6709 - lr: 0.0010
# Epoch 3/100
# 417/417 [==============================] - 13s 30ms/step - loss: 1.6155 - accuracy: 0.6709 - val_loss: 1.7336 - val_accuracy: 0.6338 - lr: 0.0010
# Epoch 4/100
# 417/417 [==============================] - 11s 27ms/step - loss: 1.6299 - accuracy: 0.6749 - val_loss: 1.6608 - val_accuracy: 0.6689 - lr: 0.0010
# Epoch 5/100
# 417/417 [==============================] - 8s 19ms/step - loss: 1.6614 - accuracy: 0.6788 - val_loss: 2.2660 - val_accuracy: 0.4995 - lr: 0.0010
# Epoch 6/100
# 417/417 [==============================] - 9s 20ms/step - loss: 1.6858 - accuracy: 0.6844 - val_loss: 1.6153 - val_accuracy: 0.7084 - lr: 0.0010
# Epoch 7/100
# 417/417 [==============================] - 9s 22ms/step - loss: 1.5478 - accuracy: 0.7258 - val_loss: 1.4403 - val_accuracy: 0.7657 - lr: 1.0000e-04
# Epoch 8/100
# 417/417 [==============================] - 9s 23ms/step - loss: 1.4743 - accuracy: 0.7413 - val_loss: 1.4050 - val_accuracy: 0.7672 - lr: 1.0000e-04
# Epoch 9/100
# 417/417 [==============================] - 9s 23ms/step - loss: 1.4079 - accuracy: 0.7609 - val_loss: 1.3834 - val_accuracy: 0.7646 - lr: 1.0000e-04
# Epoch 10/100
# 417/417 [==============================] - 9s 21ms/step - loss: 1.3692 - accuracy: 0.7632 - val_loss: 1.3547 - val_accuracy: 0.7688 - lr: 1.0000e-04
# Epoch 11/100
# 417/417 [==============================] - 8s 20ms/step - loss: 1.3260 - accuracy: 0.7696 - val_loss: 1.3316 - val_accuracy: 0.7654 - lr: 1.0000e-04
# Epoch 12/100
# 417/417 [==============================] - 9s 21ms/step - loss: 1.2889 - accuracy: 0.7770 - val_loss: 1.2776 - val_accuracy: 0.7784 - lr: 1.0000e-04
# Epoch 13/100
# 417/417 [==============================] - 9s 21ms/step - loss: 1.2467 - accuracy: 0.7842 - val_loss: 1.2486 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Epoch 14/100
# 417/417 [==============================] - 12s 28ms/step - loss: 1.2198 - accuracy: 0.7859 - val_loss: 1.2335 - val_accuracy: 0.7823 - lr: 1.0000e-04
# Epoch 15/100
# 417/417 [==============================] - 12s 29ms/step - loss: 1.1898 - accuracy: 0.7924 - val_loss: 1.2313 - val_accuracy: 0.7761 - lr: 1.0000e-04
# Epoch 16/100
# 417/417 [==============================] - 12s 30ms/step - loss: 1.1623 - accuracy: 0.7957 - val_loss: 1.2253 - val_accuracy: 0.7743 - lr: 1.0000e-04
# Epoch 17/100
# 417/417 [==============================] - 14s 32ms/step - loss: 1.1298 - accuracy: 0.8032 - val_loss: 1.1892 - val_accuracy: 0.7836 - lr: 1.0000e-04
# Epoch 18/100
# 417/417 [==============================] - 12s 29ms/step - loss: 1.1191 - accuracy: 0.8000 - val_loss: 1.2030 - val_accuracy: 0.7735 - lr: 1.0000e-04
# Epoch 19/100
# 417/417 [==============================] - 12s 29ms/step - loss: 1.0866 - accuracy: 0.8097 - val_loss: 1.1997 - val_accuracy: 0.7712 - lr: 1.0000e-04
# Epoch 20/100
# 417/417 [==============================] - 12s 29ms/step - loss: 1.0660 - accuracy: 0.8125 - val_loss: 1.1497 - val_accuracy: 0.7821 - lr: 1.0000e-04
# Epoch 21/100
# 417/417 [==============================] - 12s 29ms/step - loss: 1.0481 - accuracy: 0.8140 - val_loss: 1.1710 - val_accuracy: 0.7740 - lr: 1.0000e-04
# Epoch 22/100
# 417/417 [==============================] - 12s 29ms/step - loss: 1.0281 - accuracy: 0.8164 - val_loss: 1.1597 - val_accuracy: 0.7781 - lr: 1.0000e-04
# Epoch 23/100
# 417/417 [==============================] - 12s 30ms/step - loss: 1.0103 - accuracy: 0.8172 - val_loss: 1.1373 - val_accuracy: 0.7798 - lr: 1.0000e-04
# Epoch 24/100
# 417/417 [==============================] - 12s 29ms/step - loss: 0.9955 - accuracy: 0.8229 - val_loss: 1.1561 - val_accuracy: 0.7733 - lr: 1.0000e-04
# Epoch 25/100
# 417/417 [==============================] - 12s 29ms/step - loss: 0.9796 - accuracy: 0.8240 - val_loss: 1.1371 - val_accuracy: 0.7752 - lr: 1.0000e-04
# Epoch 26/100
# 417/417 [==============================] - 12s 29ms/step - loss: 0.9665 - accuracy: 0.8267 - val_loss: 1.0974 - val_accuracy: 0.7882 - lr: 1.0000e-04
# Epoch 27/100
# 417/417 [==============================] - 12s 29ms/step - loss: 0.9580 - accuracy: 0.8279 - val_loss: 1.1115 - val_accuracy: 0.7820 - lr: 1.0000e-04
# Epoch 28/100
# 417/417 [==============================] - 10s 23ms/step - loss: 0.9378 - accuracy: 0.8362 - val_loss: 1.1126 - val_accuracy: 0.7785 - lr: 1.0000e-04
# Epoch 29/100
# 417/417 [==============================] - 11s 26ms/step - loss: 0.9196 - accuracy: 0.8355 - val_loss: 1.0980 - val_accuracy: 0.7815 - lr: 1.0000e-04
# Epoch 30/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.9176 - accuracy: 0.8310 - val_loss: 1.0625 - val_accuracy: 0.7915 - lr: 1.0000e-04
# Epoch 31/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.9008 - accuracy: 0.8373 - val_loss: 1.0876 - val_accuracy: 0.7804 - lr: 1.0000e-04
# Epoch 32/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.8855 - accuracy: 0.8385 - val_loss: 1.0723 - val_accuracy: 0.7843 - lr: 1.0000e-04
# Epoch 33/100
# 417/417 [==============================] - 13s 31ms/step - loss: 0.8800 - accuracy: 0.8411 - val_loss: 1.0802 - val_accuracy: 0.7836 - lr: 1.0000e-04
# Epoch 34/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.8636 - accuracy: 0.8428 - val_loss: 1.0549 - val_accuracy: 0.7907 - lr: 1.0000e-04
# Epoch 35/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.8573 - accuracy: 0.8415 - val_loss: 1.0548 - val_accuracy: 0.7915 - lr: 1.0000e-04
# Epoch 36/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.8450 - accuracy: 0.8458 - val_loss: 1.0880 - val_accuracy: 0.7795 - lr: 1.0000e-04
# Epoch 37/100
# 417/417 [==============================] - 13s 31ms/step - loss: 0.8425 - accuracy: 0.8459 - val_loss: 1.0318 - val_accuracy: 0.7923 - lr: 1.0000e-04
# Epoch 38/100
# 417/417 [==============================] - 13s 31ms/step - loss: 0.8258 - accuracy: 0.8495 - val_loss: 1.0744 - val_accuracy: 0.7838 - lr: 1.0000e-04
# Epoch 39/100
# 417/417 [==============================] - 13s 31ms/step - loss: 0.8214 - accuracy: 0.8521 - val_loss: 1.0603 - val_accuracy: 0.7864 - lr: 1.0000e-04
# Epoch 40/100
# 417/417 [==============================] - 14s 34ms/step - loss: 0.8174 - accuracy: 0.8492 - val_loss: 1.0582 - val_accuracy: 0.7839 - lr: 1.0000e-04
# Epoch 41/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.8072 - accuracy: 0.8502 - val_loss: 1.0655 - val_accuracy: 0.7805 - lr: 1.0000e-04
# Epoch 42/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.7958 - accuracy: 0.8584 - val_loss: 1.0223 - val_accuracy: 0.7918 - lr: 1.0000e-04
# Epoch 43/100
# 417/417 [==============================] - 12s 30ms/step - loss: 0.7947 - accuracy: 0.8540 - val_loss: 1.0656 - val_accuracy: 0.7798 - lr: 1.0000e-04
# Epoch 44/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.7901 - accuracy: 0.8550 - val_loss: 1.0503 - val_accuracy: 0.7834 - lr: 1.0000e-04
# Epoch 45/100
# 417/417 [==============================] - 12s 30ms/step - loss: 0.7690 - accuracy: 0.8587 - val_loss: 1.0124 - val_accuracy: 0.7968 - lr: 1.0000e-04
# Epoch 46/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.7590 - accuracy: 0.8584 - val_loss: 1.0129 - val_accuracy: 0.7953 - lr: 1.0000e-04
# Epoch 47/100
# 417/417 [==============================] - 12s 30ms/step - loss: 0.7684 - accuracy: 0.8564 - val_loss: 1.0260 - val_accuracy: 0.7910 - lr: 1.0000e-04
# Epoch 48/100
# 417/417 [==============================] - 12s 29ms/step - loss: 0.7581 - accuracy: 0.8637 - val_loss: 1.0297 - val_accuracy: 0.7905 - lr: 1.0000e-04
# Epoch 49/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.7428 - accuracy: 0.8666 - val_loss: 1.0568 - val_accuracy: 0.7831 - lr: 1.0000e-04
# Epoch 50/100
# 417/417 [==============================] - 12s 29ms/step - loss: 0.7468 - accuracy: 0.8647 - val_loss: 1.0407 - val_accuracy: 0.7845 - lr: 1.0000e-04
# Epoch 51/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.7241 - accuracy: 0.8684 - val_loss: 1.0259 - val_accuracy: 0.7927 - lr: 1.0000e-05
# Epoch 52/100
# 417/417 [==============================] - 13s 31ms/step - loss: 0.7250 - accuracy: 0.8701 - val_loss: 1.0229 - val_accuracy: 0.7918 - lr: 1.0000e-05
# Epoch 53/100
# 417/417 [==============================] - 13s 31ms/step - loss: 0.7186 - accuracy: 0.8720 - val_loss: 1.0156 - val_accuracy: 0.7934 - lr: 1.0000e-05
# Epoch 54/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.7097 - accuracy: 0.8754 - val_loss: 1.0131 - val_accuracy: 0.7952 - lr: 1.0000e-05
# Epoch 55/100
# 417/417 [==============================] - 13s 30ms/step - loss: 0.7115 - accuracy: 0.8741 - val_loss: 1.0231 - val_accuracy: 0.7915 - lr: 1.0000e-05

# %%
#Saving the model
model.save('Primeiro_treino.h5')
# Out:
# c:\Users\Tex\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow import keras

model = keras.models.load_model('Primeiro_treino.h5')
# Validacao da Rede
val_loss, val_acc = model.evaluate(validation_dataset)
print('val_acc:', val_acc)
# Out:
# 417/417 [==============================] - 4s 10ms/step - loss: 1.0124 - accuracy: 0.7968
# val_acc: 0.7968000173568726

# %%
import matplotlib.pyplot as plt


# Extraindo os valores de acurácia e perda do histórico de treinamento
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Definindo o número de épocas
epochs = range(1, len(acc) + 1)

# Plotando a acurácia de treinamento e validação
plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

# Exibindo o gráfico de acurácia
plt.figure()

# Plotando a perda de treinamento e validação
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

# Exibindo o gráfico de perda
plt.show()
